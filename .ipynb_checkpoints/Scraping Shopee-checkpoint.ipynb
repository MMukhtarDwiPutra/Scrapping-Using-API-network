# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
url = "https://shopee.co.id/NPURE-CACTUS-ALOE-VERA-92-SOOTHING-GEL-PELEMBAB-LIDAH-BUAYA-ALAMI-OFFICIAL-ORIGINAL-i.18202344.2028506054"
clientUrl = urlopen(url)
page_html = clientUrl.read()
clientUrl.close()
page_soup = soup(page_html, "html.parser")
print(page_soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <link href="//cf.shopee.co.id/" rel="preconnect"/>
# <link href="//deo.shopeemobile.com/shopee/" rel="preconnect"/>
# <link href="//cv.shopee.co.id/" rel="preconnect"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no, viewport-fit=cover" name="viewport"/>
# <meta content="a540716420237b663204dbc2d7eca6c9cd4722dd" name="shopee:git-sha"/>
# <meta content="rw-v3.56.7" name="shopee:version"/>
# <script>
#       window.__PAGE_ID__ = 12;
#       window.__LOCALE__ = 'ID';
#       window.__ENV__ = 'live';
# ...

# %%
import re

# %%
# import json library
import json
import urllib
# request url

arr = []
domain = "tech"

for i in range(0,269,6):
    print(i)
#     print('https://shopee.co.id/api/v2/item/get_ratings?filter=0&flag=1&itemid=2028506054&limit=6&offset='+str(i)+'&shopid=18202344&type=5')
#     urlreq = 'https://shopee.co.id/api/v2/item/get_ratings?filter=0&flag=1&itemid=2028506054&limit=6&&offset='+str(i)+'&shopid=18202344&type=4'
    urlreq = 'https://shopee.sg/api/v2/item/get_ratings?filter=1&flag=1&itemid=7112802833&limit=6&offset='+str(i)+'&shopid=171554188&type=0'
    # get response
    response = urllib.request.urlopen(urlreq)
    # load as json
    jresponse = json.load(response)
    # write to file as pretty print
    with open('data.json', 'w') as outfile:
        json.dump(jresponse, outfile, sort_keys=True, indent=4)

    import json
    from collections import OrderedDict

    path_to_file = "data.json";

    with open(path_to_file) as data_file:
        data = OrderedDict(json.load(data_file))

    # print(data)
    length = len(data["data"]["ratings"])


    for x in range(length):
#         print(data["data"]["ratings"][x]["comment"])
#         print()
        kalimat = " ".join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ",str(data["data"]["ratings"][x]["comment"])).split())
        string = nltk.word_tokenize(kalimat)
    
        if(len(string) > 2):
            if(data["data"]["ratings"][x]["rating_star"] >= 3):
                arr.append(kalimat+"; 1; "+domain+"; "+str(data["data"]["ratings"][x]["rating_star"]))
            else:
                arr.append(kalimat+"; 0; "+domain+"; "+str(data["data"]["ratings"][x]["rating_star"]))
      
    
file = open("hasil_scraping.txt", "w", encoding="utf-8")
for s in arr:
    file.writelines(s+"\n")
file.close()
# Out:
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 66
# 72
# 78
# 84
# 90
# 96
# 102
# 108
# 114
# 120
# 126
# 132
# 138
# 144
# 150
# 156
# 162
# 168
# 174
# 180
# 186
# 192
# 198
# 204
# 210
# 216
# 222
# 228
# 234
# 240
# 246
# 252
# 258
# 264

# %%
for data in (arr):
    print(data)
    print("==")
# Out:
# Highly recommended!! Items as described!! Fast shipping!!; 1; tech; 5
# ==
# Awesome product Came very quickly and easy to set up Works flawlessly; 1; tech; 5
# ==
# Wow...delivered as promised and delivery was done within 3 days and very impressed with efficiency and it is brand new Chromecast manufactured in Jun 2020.; 1; tech; 5
# ==
# Received in good condition tested and it works well Tq seller.; 1; tech; 5
# ==
# Extremely fast delivery Tested straight away and working as expected Thanks; 1; tech; 5
# ==
# Received in good condition Very satisfied with the purchase Good quality.; 1; tech; 5
# ==
# Item came as advertised Hope it works well Thanks seller; 1; tech; 5
# ==
# Fast delivery and it work well Thanks; 1; tech; 5
# ==
# Good quality set original google chromecast I tested immediately upon receiving It works well on my Xiao mi smart tv I cast dramas from phone to tv easily. Thanks seller!; 1; tech; 5
# ==
# ...

# %%
import io

# %%
for data in (arr):
    print(data)
    print("==")
# Out:
# maaf ka, saya pesen ini juga tapi cuma ada headset slimming pant sama cassing aja wkwk; 0; tech; 1
# ==
# Korupsi!!!; 0; tech; 1
# ==
# Kunci tidak berfungsi padahal angkanya sudah di 000 tapi tidak terbuka2🤔😡; 0; tech; 1
# ==
# Tlg dibantu retur hf ny fg sdh rusak  jd  tlg bantu retur ny🙏 nnt bintang saya ganti ; 0; tech; 1
# ==
# Barang tidak ada; 0; tech; 1
# ==
# Beli 6 item yg dikirim cuma 5 item, barang yg ini gak di kirim; 0; tech; 1
# ==
# Ada harga ada kualitas. Ya murah lah.
# Respon penjual sangat jelek, lama dan bertele.
#
# Barang dikirim tidak lengkap. Tidak dikonfirmasi dan tidak diinfokan juga sebelumnya.
#
# Harus cek barang satu persatu. Kalau tidak bakal kecolongan
#
# Ujung2nya barang refund karna tidak dikirim.; 0; tech; 1
# ==
# intinya barang yang saya pesan rusak, dan respon dari penjual gak ada. ; 0; tech; 1
# ==
# Ga dikirim; 0; tech; 1
# ==
# Ada pesanan yang tidak dikirim oleh seller, artinya proses checking barang sblm dikirim kurang baik; 0; tech; 1
# ...

# %%
from googletrans import Translator
translator = Translator()
print(translator.translate('Makasiih..cepet tanggap sellernya ramah..semoga produknya cocok di aku yaaa..so far enak dingin ke kulit yg lagi sensi merah dan gatel..smg bisa nyembuhin gatelnya...', dest="EN").text)
# Out:
# Makasiih..cepet response ramah..semoga sellernya products fit in I yaaa..so tasty cold to the skin far more sensi mouth red and could gatel..smg nyembuhin gatelnya ...

# %%
type(arr[1])
import re

# %%
arrayTesData = []
for i in range(len(arr)):
    string = str(arr[i])
    string = " ".join(re.sub("[^A-Za-z0-9]+", " ", string).split())
#     print(string)
    print(translator.translate(string, dest="EN").text)
# Out:
# iniii how does sbenernyaaajangan create customer disappointed kak like this I reply that compensation
# The color is broken white but a lot of sewing machine oil stains may bececeran that time considered yaa especially white color thin material can bangettttt dihargain 15rb ya knit suit Moreover engga same wares image is an honest yes photo must fit the product being sold Ok
# Bsjsjjsjsjskdkkslslslksjwnwnmsnamwmnansbsbdbvdvdbdjddkdjdjdhdhgdgdhdjsjsjsjshsgsgshhsjsjsjsbsbshhdhdhdhdhdhrhrhdhhdjdiekekdjdjjdh
# Fast delivery of goods arrived safely but goods do not fit the image and stands for
# Which sells bangkeeee Bau bensinnn okay lahh woii thin material according to the price but this sumpaahhh direndem liter petrol can ilang ga se yaaa
# REGRET WOI's this nice photo pardon her big oversized kyk dateng Thin duster big kecilllllll short sleeve yah kak please enter tu photo corresponding cheated just the same stuff is hoping really that good stuff PLEASE discretion dateng YES
# ...

# %%
https://shopee.co.id/api/v2/item/get_ratings?filter=0&flag=1&itemid=2028506054&limit=6&offset=12&shopid=18202344&type=5
https://shopee.co.id/api/v2/item/get_ratings?filter=0&flag=1&itemid=2028506054&limit=6&offset=18&shopid=18202344&type=5
# Out:
#   File "<ipython-input-16-88da025c0d4e>", line 1
#     import shopee-api
#                  ^
# SyntaxError: invalid syntax
